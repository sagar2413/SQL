# %%
import pandas as pd
import sys
import os

# %%
df = pd.read_csv("C:/Users/saura/OneDrive/Desktop/sql/Basics/Pincode.csv", sep=",")

# %%
df.head()
# Out:
#        officename  pincode officeType Deliverystatus divisionname regionname  \
# 0         Ada B.O   504293        B.O       Delivery     Adilabad  Hyderabad
# 1  Andugulpet B.O   504231        B.O       Delivery     Adilabad  Hyderabad
# 2     Annaram B.O   504201        B.O       Delivery     Adilabad  Hyderabad
# 3    Arli (T) B.O   504312        B.O       Delivery     Adilabad  Hyderabad
# 4     Bambara B.O   504295        B.O       Delivery     Adilabad  Hyderabad
#
#        circlename       Taluk Districtname       statename
# 0  Andhra Pradesh    Asifabad     Adilabad  ANDHRA PRADESH
# 1  Andhra Pradesh  Luxettipet     Adilabad  ANDHRA PRADESH
# 2  Andhra Pradesh     Chennur     Adilabad  ANDHRA PRADESH
# 3  Andhra Pradesh    Adilabad     Adilabad  ANDHRA PRADESH
# 4  Andhra Pradesh    Asifabad     Adilabad  ANDHRA PRADESH

# %%
df.columns
# Out:
# Index(['officename', 'pincode', 'officeType', 'Deliverystatus', 'divisionname',
#        'regionname', 'circlename', 'Taluk', 'Districtname', 'statename'],
#       dtype='object')

# %%
df[df['statename']=="BIHAR"]
# Out:
#                     officename  pincode officeType Deliverystatus  \
# 20177             Ahiyapur B.O   851111        B.O       Delivery
# 20178               Akopur B.O   848202        B.O       Delivery
# 20179                 Amba B.O   851112        B.O       Delivery
# 20180            Badalpura B.O   851129        B.O       Delivery
# 20181      Begusarai Court S.O   851101        S.O   Non-Delivery
# ...                        ...      ...        ...            ...
# 29231    Rampur Shyamchand B.O   844508        B.O       Delivery
# 29232      Rasulpur Enayat B.O   844114        B.O       Delivery
# 29233  Rasulpur Purusottam B.O   844505        B.O       Delivery
# 29234        Sarai Dhanesh B.O   844509        B.O       Delivery
# 29235             Yusufpur S.O   844101        S.O   Non-Delivery
#
#       divisionname   regionname circlename          Taluk Districtname  \
# 20177    Begusarai  Muzaffarpur      Bihar      Begusarai    Begusarai
# ...

# %%
df.drop([ "officeType", "Deliverystatus", "circlename"], axis=1, inplace=True)

# %%
df.head()
import openpyxl

# %%
df.to_excel("pincode_add.xlsx")
